# %%
import requests

# %%
# proff.dk API
# url = "https://proff.dk/api/search?page=2&industryCode=10158"
url = "https://proff.dk/api/search?page=2&industryCode=47479"
# unformatted_url_cvr_query = "https://www.proff.dk/api/search?query="
# proff_url_cvr_query = "https://www.proff.dk/_next/data/I4lFA8MMsWG-90DQZkuNe/search.json?q=38477935"
proff_url_cvr_query = "https://www.proff.dk/_next/data/I4lFA8MMsWG-90DQZkuNe/search.json?q=11026109"
unformatted_url_cvr_query = "https://www.proff.dk/_next/data/I4lFA8MMsWG-90DQZkuNe/search.json?q="

# %%
r = requests.get(proff_url_cvr_query)

# %%
jsonData = r.json()
print(jsonData)
# Out:
# {'pageProps': {'rolePersons': {'businessPersons': [], 'hits': 0, 'currentPage': 1, 'pages': 0}, 'hydrationData': {'searchStore': {'inactiveCompanies': None, 'shareholders': None, 'companies': {'companies': [{'mainOffice': None, 'name': 'LaundryHouse ApS', 'orgnr': '11026109', 'businessUnitId': None, 'companyId': '06KBSTI10PO', 'listingId': '11026109', 'customerId': None, 'phone': None, 'phone2': None, 'mobile': None, 'mobile2': None, 'faxNumber': None, 'homePage': None, 'email': None, 'marketingProtection': False, 'industries': [{'code': '47580', 'name': 'Maskiner og udstyr', 'description': None, 'style': None, 'companyId': '06KBSTI10PO', 'salesRank': None}, {'code': '2200', 'name': 'Tekstilmaskiner og -udstyr', 'description': None, 'style': None, 'companyId': '06KBSTI01P4', 'salesRank': None}, {'code': '47512', 'name': 'Grossister', 'description': None, 'style': None, 'companyId': '06KBSTI10NS', 'salesRank': None}], 'location': {'countryPart': 'Region Sjælland', 'county': 'Hele Land
# ...

# %%
phoneNumber = jsonData['pageProps']['hydrationData']['searchStore']['companies']['companies'][0]['phone']
print(phoneNumber is None)
# Out:
# True
